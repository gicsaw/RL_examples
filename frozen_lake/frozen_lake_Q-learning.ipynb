# %%
import gym
import numpy as np
from gym.envs.toy_text.frozen_lake import FrozenLakeEnv
#env =FrozenLakeEnv(is_slippery=False,map_name="8x8")
env =FrozenLakeEnv(is_slippery=False,map_name="4x4")
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
max_episodes=200
max_step=100
lr=0.5
gamma=0.99
epsilon0 = 0.5

# initialize
Q = np.zeros([env.observation_space.n,env.action_space.n])
epsilon=epsilon0
min_step=max_step
min_step_episode=max_episodes
for episode in range(max_episodes):
    epsilon=epsilon*0.99
    state = env.reset()
    total_reward = 0
    state_list = [state]
    win=0
    for step in range(0,max_step):
        if np.random.rand()>epsilon :
            action=np.argmax(Q[state,:])
        else:
            action=np.random.choice(env.action_space.n)
        
        state_next,reward,game_over,_ = env.step(action)
    
        if reward==0 : 
            reward=-0.01
        if reward!=1.0 and game_over==1:
            reward=-1
#            game_over=0
        # Q-Learning
        Q[state,action]= Q[state,action]+lr*(reward+gamma* np.max(Q[state_next,:])-Q[state,action])
        state=state_next
        total_reward=total_reward+reward
        state_list.append(state)
        if game_over and reward==1:
            win=1
            if step< min_step:
                min_step=step
                min_step_path=state_list
                min_step_episode=episode
        if game_over==1:
            break
            

    line_out="Episode: %d, step: %d, total_reward: %f" %(episode, step, total_reward)
    print(line_out)
    if reward==1 :
        print(state_list)
print( "min step: ", min_step, "min step episode", min_step_episode)
print("shortest path: ", min_step_path)
#print(Q)
# Out:
# Episode: 0, step: 4, total_reward: -1.040000
# Episode: 1, step: 5, total_reward: -1.050000
# Episode: 2, step: 2, total_reward: -1.020000
# Episode: 3, step: 4, total_reward: -1.040000
# Episode: 4, step: 1, total_reward: -1.010000
# Episode: 5, step: 6, total_reward: -1.060000
# Episode: 6, step: 3, total_reward: -1.030000
# Episode: 7, step: 2, total_reward: -1.020000
# Episode: 8, step: 1, total_reward: -1.010000
# Episode: 9, step: 13, total_reward: -1.130000
# Episode: 10, step: 4, total_reward: -1.040000
# Episode: 11, step: 4, total_reward: -1.040000
# Episode: 12, step: 17, total_reward: -1.170000
# Episode: 13, step: 6, total_reward: -1.060000
# Episode: 14, step: 1, total_reward: -1.010000
# Episode: 15, step: 13, total_reward: -1.130000
# Episode: 16, step: 12, total_reward: 0.880000
# [0, 4, 8, 4, 4, 8, 8, 9, 13, 13, 14, 14, 14, 15]
# Episode: 17, step: 4, total_reward: -1.040000
# Episode: 18, step: 5, total_reward: -1.050000
# Episode: 19, step: 6, total_reward: -1.060000
# Episode: 20, step: 10, total_reward: -1.100000
# Episode: 21, step: 1, total_reward: -1.010000
# Episode: 22, step: 4, total_reward: -1.040000
# Episode: 23, step: 6, total_reward: -1.060000
# Episode: 24, step: 5, total_reward: -1.050000
# Episode: 25, step: 18, total_reward: 0.820000
# [0, 0, 4, 8, 9, 10, 6, 2, 6, 10, 9, 10, 14, 13, 13, 13, 9, 13, 14, 15]
# Episode: 26, step: 4, total_reward: -1.040000
# Episode: 27, step: 10, total_reward: 0.900000
# [0, 1, 2, 3, 3, 2, 6, 2, 6, 10, 14, 15]
# Episode: 28, step: 12, total_reward: 0.880000
# [0, 4, 8, 4, 4, 8, 9, 8, 8, 8, 9, 13, 14, 15]
# Episode: 29, step: 5, total_reward: -1.050000
# Episode: 30, step: 6, total_reward: -1.060000
# Episode: 31, step: 1, total_reward: -1.010000
# Episode: 32, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode:
step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 142, step: 8, total_reward: 0.920000
# [0, 1, 0, 4, 4, 8, 9, 13, 14, 15]
# Episode: 143, step: 3, total_reward: -1.030000
# Episode: 144, step: 7, total_reward: 0.930000
# [0, 1, 2, 1, 2, 6, 10, 14, 15]
# Episode: 145, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 146, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 147, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 14, 13, 14, 15]
# Episode: 148, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 149, step: 9, total_reward: 0.910000
# [0, 1, 0, 1, 2, 6, 10, 6, 10, 14, 15]
# Episode: 150, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 151, step: 6, total_reward: 0.940000
# [0, 1, 1, 2, 6, 10, 14, 15]
# Episode: 152, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 153, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 9, 13, 14, 15]
# Episode: 154, step: 5, total_reward: -1.050000
# Episode: 155, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 156, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 157, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 158, step: 6, total_reward: 0.940000
# [0, 0, 1, 2, 6, 10, 14, 15]
# Episode: 159, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 9, 13, 14, 15]
# Episode: 160, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 161, step: 1, total_reward: -1.010000
# Episode: 162, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 163, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 164, step: 6, total_reward: 0.940000
# [0, 1, 2, 2, 6, 10, 14, 15]
# Episode: 165, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 166, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 167, step: 6, total_reward: 0.940000
# [0, 0, 1, 2, 6, 10, 14, 15]
# Episode: 168, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 169, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 170, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 171, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 9, 13, 14, 15]
# Episode: 172, step: 6, total_reward: 0.940000
# [0, 0, 4, 8, 9, 13, 14, 15]
# Episode: 173, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 14, 13, 14, 15]
# Episode: 174, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 175, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 176, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 177, step: 1, total_reward: -1.010000
# Episode: 178, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 179, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 10, 9, 13, 14, 15]
# Episode: 180, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 181, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 182, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 183, step: 2, total_reward: -1.020000
# Episode: 184, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 185, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 186, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 2, 6, 10, 14, 15]
# Episode: 187, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 188, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 189, step: 6, total_reward: 0.940000
# [0, 0, 1, 2, 6, 10, 14, 15]
# Episode: 190, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 191, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 192, step: 8, total_reward: 0.920000
# [0, 0, 1, 2, 3, 2, 6, 10, 14, 15]
# Episode: 193, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 194, step: 3, total_reward: -1.030000
# Episode: 195, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 196, step: 6, total_reward: 0.940000
# [0, 0, 1, 2, 6, 10, 14, 15]
# Episode: 197, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# Episode: 198, step: 7, total_reward: 0.930000
# [0, 1, 2, 6, 2, 6, 10, 14, 15]
# Episode: 199, step: 5, total_reward: 0.950000
# [0, 1, 2, 6, 10, 14, 15]
# min step:  5 min step episode 32
# shortest path:  [0, 1, 2, 6, 10, 14, 15]

# %%
state = env.reset()
env.render()
epsilon=0
total_reward=0
state_list=[state]
for step in range(0,max_step):
    if np.random.rand()>epsilon :
        action=np.argmax(Q[state,:])
    else:
        action=np.random.choice(env.action_space.n)    
    state_next,reward,game_over,_ = env.step(action)
#    if reward==0 : 
#       reward=-0.01
    if reward!=1.0 and game_over==1:
        reward=-1
            
    state=state_next
    total_reward=total_reward+reward
    state_list.append(state)
    if game_over and reward==1:
        win=1
        if step< min_step:
            min_step=step
            min_step_path=state_list
            min_step_episode=episode
    env.render()
    if game_over==1:
        break
print(total_reward)
print(step)
print(state_list)
# Out:
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Right)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
#   (Down)
# SFFFFFFF
# FFFFFFFF
# FFFHFFFF
# FFFFFHFF
# FFFHFFFF
# FHHFFFHF
# FHFFHFHF
# FFFHFFFG
# 1.0
# 13
# [0, 1, 2, 10, 18, 26, 27, 28, 36, 37, 38, 39, 47, 55, 63]
